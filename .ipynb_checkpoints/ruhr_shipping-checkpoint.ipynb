# %%
# Configure plotting in Jupyter
from matplotlib import pyplot as plt
# %matplotlib inline
plt.rcParams.update({
    'figure.figsize': (7.5, 7.5)})
# Seed random number generator
from numpy import random as nprand
seed = hash("Network Science in Python") % 2**32
nprand.seed(seed)

# %%
import networkx as nx
import pandas as pd
from pandas import ExcelWriter
from pandas import ExcelFile

# %%
dfnodes = pd.read_excel('Nodes.xlsx', index_col='ID')
print (dfnodes)
# Out:
#                    City  Demand
# ID
# 1              Duisburg  164.60
# 2   Mülheim an der Ruhr   57.10
# 3                 Essen  189.92
# 4             Dortmund   188.87
# 5       Castrop Rauxel    24.42
# 6                Herne    51.81
# 7        Gelsenkirchen    85.75
# 8               Bottrop   39.59
# 9            Oberhausen   70.61
# 10            Dinslaken   22.50
# 11                 Hamm   59.08
# 12               Voerde   11.94
# 13                Wesel   20.05
# 14                Hünxe    4.56
# 15              Dorsten   24.90
# 16      Haltern am See    12.82
# 17              Datteln   11.82
# 18                Lünen   28.31
# 19              Waltrop    9.89
# 20                 Marl   28.62
# 21               Xanten    7.10
# 22            Rheinberg   10.48

# %%
dfedges = pd.read_excel('Edges.xlsx')
print (dfedges)
# Out:
#     Source  Target  Distance  Time  Price
# 0        1       2         9  0.74   0.30
# 1        1       9         3  0.25   0.09
# 2        1      10        43  3.24   1.29
# 3        1      22        71  4.08   2.13
# 4        3       7         6  0.90   0.18
# 5        3       8         2  0.25   0.06
# 6        3       9        11  0.90   0.33
# 7        4       5        21  1.22   0.63
# 8        4      19        20  1.27   0.60
# 9        5       6         3  0.50   0.09
# 10       6       7        13  1.28   0.39
# 11       7       8         8  0.71   0.24
# 12       8       9         9  0.90   0.27
# 13      10      12         1  0.08   0.03
# 14      11      18        26  2.48   0.78
# 15      12      20        38  4.33   1.14
# 16      13      14        13  2.01   0.39
# 17      13      21        25  1.08   0.75
# 18      13      22        31  1.23   0.93
# 19      14      15        17  2.07   0.51
# 20      15      20        11  1.03   0.33
# 21      16      17        10  1.32   0.30
# 22      16      20        17  1.52   0.51
# 23      17      19         5  0.30   0.15
# 24      18      19         8  0.75   0.24

# %%
G = nx.from_pandas_edgelist(dfedges, 'Source','Target',['Distance', 'Time','Price'],create_using=nx.Graph)

# %%
print(dfnodes)
# Out:
#                    City  Demand
# ID
# 1              Duisburg  164.60
# 2   Mülheim an der Ruhr   57.10
# 3                 Essen  189.92
# 4             Dortmund   188.87
# 5       Castrop Rauxel    24.42
# 6                Herne    51.81
# 7        Gelsenkirchen    85.75
# 8               Bottrop   39.59
# 9            Oberhausen   70.61
# 10            Dinslaken   22.50
# 11                 Hamm   59.08
# 12               Voerde   11.94
# 13                Wesel   20.05
# 14                Hünxe    4.56
# 15              Dorsten   24.90
# 16      Haltern am See    12.82
# 17              Datteln   11.82
# 18                Lünen   28.31
# 19              Waltrop    9.89
# 20                 Marl   28.62
# 21               Xanten    7.10
# 22            Rheinberg   10.48

# %%
nx.set_node_attributes(G, dfnodes['City'], 'City')

# %%
nx.set_node_attributes(G, dfnodes['Demand'], 'Demand')

# %%
# Draw network 

d = dict(dfnodes['Demand'])
pos = nx.spring_layout(G, seed=7) 
fig = plt.figure(figsize=(20,20))
plt.title('Ruhr Shipment Graph')
ax = plt.subplot(1, 1, 1)
nx.draw_networkx(G, pos=pos, nodelist=d.keys(), node_size=[v * 10 for v in d.values()], node_color='#7f7fff')
for e in G.edges:
    nx.draw_networkx_edges(
        G, pos=pos, edgelist=[e],edge_color='#7f7fff', alpha=0.5, arrows=False)
ax.set_aspect(1)
nx.draw_networkx_labels(G,pos, alpha=0.7)
labels = nx.get_edge_attributes(G,'Distance') # Label on the edges are distances
nx.draw_networkx_edge_labels(G, pos, edge_labels=labels)
nx.draw_networkx_edges(G , pos = pos, width=dfedges['Price']*20, alpha=0.3) #edge width represents price
fig.savefig('ruhr shipments')

# %%
#returns frequency for degree 0, 1,2...
nx.degree_histogram(G)
# Out:
# [0, 3, 11, 7, 1]

# %%
degree_centrality=nx.degree_centrality(G)
degree_centrality
# Out:
# {1: 0.19047619047619047,
#  2: 0.047619047619047616,
#  9: 0.14285714285714285,
#  10: 0.09523809523809523,
#  22: 0.09523809523809523,
#  3: 0.14285714285714285,
#  7: 0.14285714285714285,
#  8: 0.14285714285714285,
#  4: 0.09523809523809523,
#  5: 0.09523809523809523,
#  19: 0.14285714285714285,
#  6: 0.09523809523809523,
#  12: 0.09523809523809523,
#  11: 0.047619047619047616,
#  18: 0.09523809523809523,
#  20: 0.14285714285714285,
#  13: 0.14285714285714285,
#  14: 0.09523809523809523,
#  21: 0.047619047619047616,
#  15: 0.09523809523809523,
#  16: 0.09523809523809523,
#  17: 0.09523809523809523}

# %%
betweenness_centrality=nx.betweenness_centrality(G)
betweenness_centrality
# Out:
# {1: 0.3595238095238096,
#  2: 0.0,
#  9: 0.23333333333333336,
#  10: 0.16666666666666669,
#  22: 0.14047619047619048,
#  3: 0.08095238095238096,
#  7: 0.1761904761904762,
#  8: 0.08095238095238096,
#  4: 0.1523809523809524,
#  5: 0.14761904761904762,
#  19: 0.2904761904761905,
#  6: 0.15714285714285717,
#  12: 0.1642857142857143,
#  11: 0.0,
#  18: 0.09523809523809525,
#  20: 0.3166666666666667,
#  13: 0.16904761904761906,
#  14: 0.1142857142857143,
#  21: 0.0,
#  15: 0.13095238095238096,
#  16: 0.2571428571428572,
#  17: 0.2380952380952381}

# %%
closeness_centrality=nx.closeness_centrality(G)
closeness_centrality
# Out:
# {1: 0.2876712328767123,
#  2: 0.22580645161290322,
#  9: 0.2692307692307692,
#  10: 0.27631578947368424,
#  22: 0.24705882352941178,
#  3: 0.25609756097560976,
#  7: 0.2441860465116279,
#  8: 0.25609756097560976,
#  4: 0.23076923076923078,
#  5: 0.22826086956521738,
#  19: 0.2441860465116279,
#  6: 0.23333333333333334,
#  12: 0.2727272727272727,
#  11: 0.1693548387096774,
#  18: 0.20192307692307693,
#  20: 0.28378378378378377,
#  13: 0.2441860465116279,
#  14: 0.2413793103448276,
#  21: 0.19811320754716982,
#  15: 0.2441860465116279,
#  16: 0.26582278481012656,
#  17: 0.25301204819277107}

# %%
path = nx.shortest_path(G, 1, 19, weight="Distance")
print(path)
# Out:
# [1, 9, 8, 7, 6, 5, 4, 19]

# %%
for v in G.nodes:
    for u in G.nodes:
        print('shortest path between ', v ,'and' , u)
        path=nx.shortest_path(G, u,v, weight='Distance')
        print(path)
# Out:
# shortest path between  1 and 1
# [1]
# shortest path between  1 and 2
# [2, 1]
# shortest path between  1 and 9
# [9, 1]
# shortest path between  1 and 10
# [10, 1]
# shortest path between  1 and 22
# [22, 1]
# shortest path between  1 and 3
# [3, 9, 1]
# shortest path between  1 and 7
# [7, 3, 9, 1]
# shortest path between  1 and 8
# [8, 9, 1]
# shortest path between  1 and 4
# [4, 5, 6, 7, 8, 9, 1]
# shortest path between  1 and 5
# [5, 6, 7, 3, 9, 1]
# shortest path between  1 and 19
# [19, 4, 5, 6, 7, 8, 9, 1]
# shortest path between  1 and 6
# [6, 7, 3, 9, 1]
# shortest path between  1 and 12
# [12, 10, 1]
# shortest path between  1 and 11
# [11, 18, 19, 4, 5, 6, 7, 8, 9, 1]
# shortest path between  1 and 18
# [18, 19, 4, 5, 6, 7, 8, 9, 1]
# shortest path between  1 and 20
# [20, 12, 10, 1]
# shortest path between  1 and 13
# [13, 22, 1]
# shortest path between  1 and 14
# [14, 15, 20, 12, 10, 1]
# shortest path between  1 and 21
# [21, 13, 22, 1]
# shortest path between  1 and 15
# [15, 20, 12, 10, 1]
# shortest path between  1 and 16
# [16, 17, 19, 4, 5, 6, 7, 8, 9, 1]
# shortest path between  1 and 17
# [17, 19, 4, 5, 6, 7, 8, 9, 1]
# shortest path between  2 and 1
# [1, 2]
# shortest path between  2 and 2
# [2]
# shortest path between  2 and 9
# [9, 1, 2]
# shortest path between  2 and 10
# [10, 1, 2]
# shortest path between  2 and 22
# [22, 1, 2]
# shortest path between  2 and 3
# [3, 9, 1, 2]
# shortest path between  2 and 7
# [7, 3, 9, 1, 2]
# shortest path between  2 and 8
# [8, 9, 1, 2]
# shortest path between  2 and 4
# [4, 5, 6, 7, 8, 9, 1, 2]
# shortest path between  2 and 5
# [5, 6, 7, 3, 9, 1, 2]
# shortest path between  2 and 19
# [19, 4, 5, 6, 7, 8, 9, 1, 2]
# shortest path between  2 and 6
# [6, 7, 3, 9, 1, 2]
# shortest path between  2 and 12
# [12, 10, 1, 2]
# shortest path between  2 and 11
# [11, 18, 19, 4, 5, 6, 7, 8, 9, 1, 2]
# shortest path between  2 and 18
# [18, 19, 4, 5, 6, 7, 8, 9, 1, 2]
# shortest path between  2 and 20
# [20, 12, 10, 1, 2]
# shortest path between  2 and 13
# [13, 22, 1, 2]
# shortest path between  2 and 14
# [14, 15, 20, 12, 10, 1, 2]
# shortest path between  2 and 21
# [21, 13, 22, 1, 2]
# shortest path between  2 and 15
# [15, 20, 12, 10, 1, 2]
# shortest path between  2 and 16
# [16, 17, 19, 4, 5, 6, 7, 8, 9, 1, 2]
# shortest path between  2 and 17
# [17, 19, 4, 5, 6, 7, 8, 9, 1, 2]
# shortest path between  9 and 1
# [1, 9]
# shortest path between  9 and 2
# [2, 1, 9]
# shortest path between  9 and 9
# [9]
# shortest path between  9 and 10
# [10, 1, 9]
# shortest path between  9 and 22
# [22, 1, 9]
# shortest path between  9 and 3
# [3, 9]
# shortest path between  9 and 7
# [7, 3, 9]
# shortest path between  9 and 8
# [8, 9]
# shortest path between  9 and 4
# [4, 5, 6, 7, 8, 9]
# shortest path between  9 and 5
# [5, 6, 7, 3, 9]
# shortest path between  9 and 19
# [19, 4, 5, 6, 7, 8, 9]
# shortest path between  9 and 6
# [6, 7, 3, 9]
# shortest path between  9 and 12
# [12, 10, 1, 9]
# shortest path between  9 and 11
# [11, 18, 19, 4, 5, 6, 7, 8, 9]
# shortest path between  9 and 18
# [18, 19, 4, 5, 6, 7, 8, 9]
# shortest path between  9 and 20
# [20, 12, 10, 1, 9]
# shortest path between  9 and 13
# [13, 22, 1, 9]
# shortest path between  9 and 14
# [14, 15, 20, 12, 10, 1, 9]
# shortest path between  9 and 21
# [21, 13, 22, 1, 9]
# shortest path between  9 and 15
# [15, 20, 12, 10, 1, 9]
# shortest path between  9 and 16
# [16, 17, 19, 4, 5, 6, 7, 8, 9]
# shortest path between  9 and 17
# [17, 19, 4, 5, 6, 7, 8, 9]
# shortest path between  10 and 1
# [1, 10]
# shortest path between  10 and 2
# [2, 1, 10]
# shortest path between  10 and 9
# [9, 1, 10]
# shortest path between  10 and 10
# [10]
# shortest path between  10 and 22
# [22, 13, 14, 15, 20, 12, 10]
# shortest path between  10 and 3
# [3, 9, 1, 10]
# shortest path between  10 and 7
# [7, 3, 9, 1, 10]
# shortest path between  10 and 8
# [8, 9, 1, 10]
# shortest path between  10 and 4
# [4, 19, 17, 16, 20, 12, 10]
# shortest path between  10 and 5
# [5, 6, 7, 3, 9, 1, 10]
# shortest path between  10 and 19
# [19, 17, 16, 20, 12, 10]
# shortest path between  10 and 6
# [6, 7, 3, 9, 1, 10]
# shortest path between  10 and 12
# [12, 10]
# shortest path between  10 and 11
# [11, 18, 19, 17, 16, 20, 12, 10]
# shortest path between  10 and 18
# [18, 19, 17, 16, 20, 12, 10]
# shortest path between  10 and 20
# [20, 12, 10]
# shortest path between  10 and 13
# [13, 14, 15, 20, 12, 10]
# shortest path between  10 and 14
# [14, 15, 20, 12, 10]
# shortest path between  10 and 21
# [21, 13, 14, 15, 20, 12, 10]
# shortest path between  10 and 15
# [15, 20, 12, 10]
# shortest path between  10 and 16
# [16, 20, 12, 10]
# shortest path between  10 and 17
# [17, 16, 20, 12, 10]
# shortest path between  22 and 1
# [1, 22]
# shortest path between  22 and 2
# [2, 1, 22]
# shortest path between  22 and 9
# [9, 1, 22]
# shortest path between  22 and 10
# [10, 12, 20, 15, 14, 13, 22]
# shortest path between  22 and 22
# [22]
# shortest path between  22 and 3
# [3, 9, 1, 22]
# shortest path between  22 and 7
# [7, 3, 9, 1, 22]
# shortest path between  22 and 8
# [8, 9, 1, 22]
# shortest path between  22 and 4
# [4, 19, 17, 16, 20, 15, 14, 13, 22]
# shortest path between  22 and 5
# [5, 6, 7, 3, 9, 1, 22]
# shortest path between  22 and 19
# [19, 17, 16, 20, 15, 14, 13, 22]
# shortest path between  22 and 6
# [6, 7, 3, 9, 1, 22]
# shortest path between  22 and 12
# [12, 20, 15, 14, 13, 22]
# shortest path between  22 and 11
# [11, 18, 19, 17, 16, 20, 15, 14, 13, 22]
# shortest path between  22 and 18
# [18, 19, 17, 16, 20, 15, 14, 13, 22]
# shortest path between  22 and 20
# [20, 15, 14, 13, 22]
# shortest path between  22 and 13
# [13, 22]
# shortest path between  22 and 14
# [14, 13, 22]
# shortest path between  22 and 21
# [21, 13, 22]
# shortest path between  22 and 15
# [15, 14, 13, 22]
# shortest path between  22 and 16
# [16, 20, 15, 14, 13, 22]
# shortest path between  22 and 17
# [17, 16, 20, 15, 14, 13, 22]
# shortest path between  3 and 1
# [1, 9, 3]
# shortest path between  3 and 2
# [2, 1, 9, 3]
# shortest path between  3 and 9
# [9, 3]
# shortest path between  3 and 10
# [10, 1, 9, 3]
# shortest path between  3 and 22
# [22, 1, 9, 3]
# shortest path between  3 and 3
# [3]
# shortest path between  3 and 7
# [7, 3]
# shortest path between  3 and 8
# [8, 3]
# shortest path between  3 and 4
# [4, 5, 6, 7, 3]
# shortest path between  3 and 5
# [5, 6, 7, 3]
# shortest path between  3 and 19
# [19, 4, 5, 6, 7, 3]
# shortest path between  3 and 6
# [6, 7, 3]
# shortest path between  3 and 12
# [12, 10, 1, 9, 3]
# shortest path between  3 and 11
# [11, 18, 19, 4, 5, 6, 7, 3]
# shortest path between  3 and 18
# [18, 19, 4, 5, 6, 7, 3]
# shortest path between  3 and 20
# [20, 16, 17, 19, 4, 5, 6, 7, 3]
# shortest path between  3 and 13
# [13, 22, 1, 9, 3]
# shortest path between  3 and 14
# [14, 15, 20, 16, 17, 19, 4, 5, 6, 7, 3]
# shortest path between  3 and 21
# [21, 13, 22, 1, 9, 3]
# shortest path between  3 and 15
# [15, 20, 16, 17, 19, 4, 5, 6, 7, 3]
# shortest path between  3 and 16
# [16, 17, 19, 4, 5, 6, 7, 3]
# shortest path between  3 and 17
# [17, 19, 4, 5, 6, 7, 3]
# shortest path between  7 and 1
# [1, 9, 3, 7]
# shortest path between  7 and 2
# [2, 1, 9, 3, 7]
# shortest path between  7 and 9
# [9, 3, 7]
# shortest path between  7 and 10
# [10, 1, 9, 3, 7]
# shortest path between  7 and 22
# [22, 1, 9, 3, 7]
# shortest path between  7 and 3
# [3, 7]
# shortest path between  7 and 7
# [7]
# shortest path between  7 and 8
# [8, 7]
# shortest path between  7 and 4
# [4, 5, 6, 7]
# shortest path between  7 and 5
# [5, 6, 7]
# shortest path between  7 and 19
# [19, 4, 5, 6, 7]
# shortest path between  7 and 6
# [6, 7]
# shortest path between  7 and 12
# [12, 10, 1, 9, 3, 7]
# shortest path between  7 and 11
# [11, 18, 19, 4, 5, 6, 7]
# shortest path between  7 and 18
# [18, 19, 4, 5, 6, 7]
# shortest path between  7 and 20
# [20, 16, 17, 19, 4, 5, 6, 7]
# shortest path between  7 and 13
# [13, 22, 1, 9, 3, 7]
# shortest path between  7 and 14
# [14, 15, 20, 16, 17, 19, 4, 5, 6, 7]
# shortest path between  7 and 21
# [21, 13, 22, 1, 9, 3, 7]
# shortest path between  7 and 15
# [15, 20, 16, 17, 19, 4, 5, 6, 7]
# shortest path between  7 and 16
# [16, 17, 19, 4, 5, 6, 7]
# shortest path between  7 and 17
# [17, 19, 4, 5, 6, 7]
# shortest path between  8 and 1
# [1, 9, 8]
# shortest path between  8 and 2
# [2, 1, 9, 8]
# shortest path between  8 and 9
# [9, 8]
# shortest path between  8 and 10
# [10, 1, 9, 8]
# shortest path between  8 and 22
# [22, 1, 9, 8]
# shortest path between  8 and 3
# [3, 8]
# shortest path between  8 and 7
# [7, 8]
# shortest path between  8 and 8
# [8]
# shortest path between  8 and 4
# [4, 5, 6, 7, 8]
# shortest path between  8 and 5
# [5, 6, 7, 8]
# shortest path between  8 and 19
# [19, 4, 5, 6, 7, 8]
# shortest path between  8 and 6
# [6, 7, 8]
# shortest path between  8 and 12
# [12, 10, 1, 9, 8]
# shortest path between  8 and 11
# [11, 18, 19, 4, 5, 6, 7, 8]
# shortest path between  8 and 18
# [18, 19, 4, 5, 6, 7, 8]
# shortest path between  8 and 20
# [20, 12, 10, 1, 9, 8]
# shortest path between  8 and 13
# [13, 22, 1, 9, 8]
# shortest path between  8 and 14
# [14, 15, 20, 12, 10, 1, 9, 8]
# shortest path between  8 and 21
# [21, 13, 22, 1, 9, 8]
# shortest path between  8 and 15
# [15, 20, 12, 10, 1, 9, 8]
# shortest path between  8 and 16
# [16, 17, 19, 4, 5, 6, 7, 8]
# shortest path between  8 and 17
# [17, 19, 4, 5, 6, 7, 8]
# shortest path between  4 and 1
# [1, 9, 8, 7, 6, 5, 4]
# shortest path between  4 and 2
# [2, 1, 9, 8, 7, 6, 5, 4]
# shortest path between  4 and 9
# [9, 8, 7, 6, 5, 4]
# shortest path between  4 and 10
# [10, 12, 20, 16, 17, 19, 4]
# shortest path between  4 and 22
# [22, 13, 14, 15, 20, 16, 17, 19, 4]
# shortest path between  4 and 3
# [3, 7, 6, 5, 4]
# shortest path between  4 and 7
# [7, 6, 5, 4]
# shortest path between  4 and 8
# [8, 7, 6, 5, 4]
# shortest path between  4 and 4
# [4]
# shortest path between  4 and 5
# [5, 4]
# shortest path between  4 and 19
# [19, 4]
# shortest path between  4 and 6
# [6, 5, 4]
# shortest path between  4 and 12
# [12, 20, 16, 17, 19, 4]
# shortest path between  4 and 11
# [11, 18, 19, 4]
# shortest path between  4 and 18
# [18, 19, 4]
# shortest path between  4 and 20
# [20, 16, 17, 19, 4]
# shortest path between  4 and 13
# [13, 14, 15, 20, 16, 17, 19, 4]
# shortest path between  4 and 14
# [14, 15, 20, 16, 17, 19, 4]
# shortest path between  4 and 21
# [21, 13, 14, 15, 20, 16, 17, 19, 4]
# shortest path between  4 and 15
# [15, 20, 16, 17, 19, 4]
# shortest path between  4 and 16
# [16, 17, 19, 4]
# shortest path between  4 and 17
# [17, 19, 4]
# shortest path between  5 and 1
# [1, 9, 3, 7, 6, 5]
# shortest path between  5 and 2
# [2, 1, 9, 3, 7, 6, 5]
# shortest path between  5 and 9
# [9, 8, 7, 6, 5]
# shortest path between  5 and 10
# [10, 1, 9, 3, 7, 6, 5]
# shortest path between  5 and 22
# [22, 1, 9, 3, 7, 6, 5]
# shortest path between  5 and 3
# [3, 7, 6, 5]
# shortest path between  5 and 7
# [7, 6, 5]
# shortest path between  5 and 8
# [8, 7, 6, 5]
# shortest path between  5 and 4
# [4, 5]
# shortest path between  5 and 5
# [5]
# shortest path between  5 and 19
# [19, 4, 5]
# shortest path between  5 and 6
# [6, 5]
# shortest path between  5 and 12
# [12, 10, 1, 9, 3, 7, 6, 5]
# shortest path between  5 and 11
# [11, 18, 19, 4, 5]
# shortest path between  5 and 18
# [18, 19, 4, 5]
# shortest path between  5 and 20
# [20, 16, 17, 19, 4, 5]
# shortest path between  5 and 13
# [13, 14, 15, 20, 16, 17, 19, 4, 5]
# shortest path between  5 and 14
# [14, 15, 20, 16, 17, 19, 4, 5]
# shortest path between  5 and 21
# [21, 13, 14, 15, 20, 16, 17, 19, 4, 5]
# shortest path between  5 and 15
# [15, 20, 16, 17, 19, 4, 5]
# shortest path between  5 and 16
# [16, 17, 19, 4, 5]
# shortest path between  5 and 17
# [17, 19, 4, 5]
# shortest path between  19 and 1
# [1, 9, 8, 7, 6, 5, 4, 19]
# shortest path between  19 and 2
# [2, 1, 9, 8, 7, 6, 5, 4, 19]
# shortest path between  19 and 9
# [9, 8, 7, 6, 5, 4, 19]
# shortest path between  19 and 10
# [10, 12, 20, 16, 17, 19]
# shortest path between  19 and 22
# [22, 13, 14, 15, 20, 16, 17, 19]
# shortest path between  19 and 3
# [3, 7, 6, 5, 4, 19]
# shortest path between  19 and 7
# [7, 6, 5, 4, 19]
# shortest path between  19 and 8
# [8, 7, 6, 5, 4, 19]
# shortest path between  19 and 4
# [4, 19]
# shortest path between  19 and 5
# [5, 4, 19]
# shortest path between  19 and 19
# [19]
# shortest path between  19 and 6
# [6, 5, 4, 19]
# shortest path between  19 and 12
# [12, 20, 16, 17, 19]
# shortest path between  19 and 11
# [11, 18, 19]
# shortest path between  19 and 18
# [18, 19]
# shortest path between  19 and 20
# [20, 16, 17, 19]
# shortest path between  19 and 13
# [13, 14, 15, 20, 16, 17, 19]
# shortest path between  19 and 14
# [14, 15, 20, 16, 17, 19]
# shortest path between  19 and 21
# [21, 13, 14, 15, 20, 16, 17, 19]
# shortest path between  19 and 15
# [15, 20, 16, 17, 19]
# shortest path between  19 and 16
# [16, 17, 19]
# shortest path between  19 and 17
# [17, 19]
# shortest path between  6 and 1
# [1, 9, 3, 7, 6]
# shortest path between  6 and 2
# [2, 1, 9, 3, 7, 6]
# shortest path between  6 and 9
# [9, 8, 7, 6]
# shortest path between  6 and 10
# [10, 1, 9, 3, 7, 6]
# shortest path between  6 and 22
# [22, 1, 9, 3, 7, 6]
# shortest path between  6 and 3
# [3, 7, 6]
# shortest path between  6 and 7
# [7, 6]
# shortest path between  6 and 8
# [8, 7, 6]
# shortest path between  6 and 4
# [4, 5, 6]
# shortest path between  6 and 5
# [5, 6]
# shortest path between  6 and 19
# [19, 4, 5, 6]
# shortest path between  6 and 6
# [6]
# shortest path between  6 and 12
# [12, 10, 1, 9, 3, 7, 6]
# shortest path between  6 and 11
# [11, 18, 19, 4, 5, 6]
# shortest path between  6 and 18
# [18, 19, 4, 5, 6]
# shortest path between  6 and 20
# [20, 16, 17, 19, 4, 5, 6]
# shortest path between  6 and 13
# [13, 14, 15, 20, 16, 17, 19, 4, 5, 6]
# shortest path between  6 and 14
# [14, 15, 20, 16, 17, 19, 4, 5, 6]
# shortest path between  6 and 21
# [21, 13, 14, 15, 20, 16, 17, 19, 4, 5, 6]
# shortest path between  6 and 15
# [15, 20, 16, 17, 19, 4, 5, 6]
# shortest path between  6 and 16
# [16, 17, 19, 4, 5, 6]
# shortest path between  6 and 17
# [17, 19, 4, 5, 6]
# shortest path between  12 and 1
# [1, 10, 12]
# shortest path between  12 and 2
# [2, 1, 10, 12]
# shortest path between  12 and 9
# [9, 1, 10, 12]
# shortest path between  12 and 10
# [10, 12]
# shortest path between  12 and 22
# [22, 13, 14, 15, 20, 12]
# shortest path between  12 and 3
# [3, 9, 1, 10, 12]
# shortest path between  12 and 7
# [7, 3, 9, 1, 10, 12]
# shortest path between  12 and 8
# [8, 9, 1, 10, 12]
# shortest path between  12 and 4
# [4, 19, 17, 16, 20, 12]
# shortest path between  12 and 5
# [5, 6, 7, 3, 9, 1, 10, 12]
# shortest path between  12 and 19
# [19, 17, 16, 20, 12]
# shortest path between  12 and 6
# [6, 7, 3, 9, 1, 10, 12]
# shortest path between  12 and 12
# [12]
# shortest path between  12 and 11
# [11, 18, 19, 17, 16, 20, 12]
# shortest path between  12 and 18
# [18, 19, 17, 16, 20, 12]
# shortest path between  12 and 20
# [20, 12]
# shortest path between  12 and 13
# [13, 14, 15, 20, 12]
# shortest path between  12 and 14
# [14, 15, 20, 12]
# shortest path between  12 and 21
# [21, 13, 14, 15, 20, 12]
# shortest path between  12 and 15
# [15, 20, 12]
# shortest path between  12 and 16
# [16, 20, 12]
# shortest path between  12 and 17
# [17, 16, 20, 12]
# shortest path between  11 and 1
# [1, 9, 8, 7, 6, 5, 4, 19, 18, 11]
# shortest path between  11 and 2
# [2, 1, 9, 8, 7, 6, 5, 4, 19, 18, 11]
# shortest path between  11 and 9
# [9, 8, 7, 6, 5, 4, 19, 18, 11]
# shortest path between  11 and 10
# [10, 12, 20, 16, 17, 19, 18, 11]
# shortest path between  11 and 22
# [22, 13, 14, 15, 20, 16, 17, 19, 18, 11]
# shortest path between  11 and 3
# [3, 7, 6, 5, 4, 19, 18, 11]
# shortest path between  11 and 7
# [7, 6, 5, 4, 19, 18, 11]
# shortest path between  11 and 8
# [8, 7, 6, 5, 4, 19, 18, 11]
# shortest path between  11 and 4
# [4, 19, 18, 11]
# shortest path between  11 and 5
# [5, 4, 19, 18, 11]
# shortest path between  11 and 19
# [19, 18, 11]
# shortest path between  11 and 6
# [6, 5, 4, 19, 18, 11]
# shortest path between  11 and 12
# [12, 20, 16, 17, 19, 18, 11]
# shortest path between  11 and 11
# [11]
# shortest path between  11 and 18
# [18, 11]
# shortest path between  11 and 20
# [20, 16, 17, 19, 18, 11]
# shortest path between  11 and 13
# [13, 14, 15, 20, 16, 17, 19, 18, 11]
# shortest path between  11 and 14
# [14, 15, 20, 16, 17, 19, 18, 11]
# shortest path between  11 and 21
# [21, 13, 14, 15, 20, 16, 17, 19, 18, 11]
# shortest path between  11 and 15
# [15, 20, 16, 17, 19, 18, 11]
# shortest path between  11 and 16
# [16, 17, 19, 18, 11]
# shortest path between  11 and 17
# [17, 19, 18, 11]
# shortest path between  18 and 1
# [1, 9, 8, 7, 6, 5, 4, 19, 18]
# shortest path between  18 and 2
# [2, 1, 9, 8, 7, 6, 5, 4, 19, 18]
# shortest path between  18 and 9
# [9, 8, 7, 6, 5, 4, 19, 18]
# shortest path between  18 and 10
# [10, 12, 20, 16, 17, 19, 18]
# shortest path between  18 and 22
# [22, 13, 14, 15, 20, 16, 17, 19, 18]
# shortest path between  18 and 3
# [3, 7, 6, 5, 4, 19, 18]
# shortest path between  18 and 7
# [7, 6, 5, 4, 19, 18]
# shortest path between  18 and 8
# [8, 7, 6, 5, 4, 19, 18]
# shortest path between  18 and 4
# [4, 19, 18]
# shortest path between  18 and 5
# [5, 4, 19, 18]
# shortest path between  18 and 19
# [19, 18]
# shortest path between  18 and 6
# [6, 5, 4, 19, 18]
# shortest path between  18 and 12
# [12, 20, 16, 17, 19, 18]
# shortest path between  18 and 11
# [11, 18]
# shortest path between  18 and 18
# [18]
# shortest path between  18 and 20
# [20, 16, 17, 19, 18]
# shortest path between  18 and 13
# [13, 14, 15, 20, 16, 17, 19, 18]
# shortest path between  18 and 14
# [14, 15, 20, 16, 17, 19, 18]
# shortest path between  18 and 21
# [21, 13, 14, 15, 20, 16, 17, 19, 18]
# shortest path between  18 and 15
# [15, 20, 16, 17, 19, 18]
# shortest path between  18 and 16
# [16, 17, 19, 18]
# shortest path between  18 and 17
# [17, 19, 18]
# shortest path between  20 and 1
# [1, 10, 12, 20]
# shortest path between  20 and 2
# [2, 1, 10, 12, 20]
# shortest path between  20 and 9
# [9, 1, 10, 12, 20]
# shortest path between  20 and 10
# [10, 12, 20]
# shortest path between  20 and 22
# [22, 13, 14, 15, 20]
# shortest path between  20 and 3
# [3, 7, 6, 5, 4, 19, 17, 16, 20]
# shortest path between  20 and 7
# [7, 6, 5, 4, 19, 17, 16, 20]
# shortest path between  20 and 8
# [8, 9, 1, 10, 12, 20]
# shortest path between  20 and 4
# [4, 19, 17, 16, 20]
# shortest path between  20 and 5
# [5, 4, 19, 17, 16, 20]
# shortest path between  20 and 19
# [19, 17, 16, 20]
# shortest path between  20 and 6
# [6, 5, 4, 19, 17, 16, 20]
# shortest path between  20 and 12
# [12, 20]
# shortest path between  20 and 11
# [11, 18, 19, 17, 16, 20]
# shortest path between  20 and 18
# [18, 19, 17, 16, 20]
# shortest path between  20 and 20
# [20]
# shortest path between  20 and 13
# [13, 14, 15, 20]
# shortest path between  20 and 14
# [14, 15, 20]
# shortest path between  20 and 21
# [21, 13, 14, 15, 20]
# shortest path between  20 and 15
# [15, 20]
# shortest path between  20 and 16
# [16, 20]
# shortest path between  20 and 17
# [17, 16, 20]
# shortest path between  13 and 1
# [1, 22, 13]
# shortest path between  13 and 2
# [2, 1, 22, 13]
# shortest path between  13 and 9
# [9, 1, 22, 13]
# shortest path between  13 and 10
# [10, 12, 20, 15, 14, 13]
# shortest path between  13 and 22
# [22, 13]
# shortest path between  13 and 3
# [3, 9, 1, 22, 13]
# shortest path between  13 and 7
# [7, 3, 9, 1, 22, 13]
# shortest path between  13 and 8
# [8, 9, 1, 22, 13]
# shortest path between  13 and 4
# [4, 19, 17, 16, 20, 15, 14, 13]
# shortest path between  13 and 5
# [5, 4, 19, 17, 16, 20, 15, 14, 13]
# shortest path between  13 and 19
# [19, 17, 16, 20, 15, 14, 13]
# shortest path between  13 and 6
# [6, 5, 4, 19, 17, 16, 20, 15, 14, 13]
# shortest path between  13 and 12
# [12, 20, 15, 14, 13]
# shortest path between  13 and 11
# [11, 18, 19, 17, 16, 20, 15, 14, 13]
# shortest path between  13 and 18
# [18, 19, 17, 16, 20, 15, 14, 13]
# shortest path between  13 and 20
# [20, 15, 14, 13]
# shortest path between  13 and 13
# [13]
# shortest path between  13 and 14
# [14, 13]
# shortest path between  13 and 21
# [21, 13]
# shortest path between  13 and 15
# [15, 14, 13]
# shortest path between  13 and 16
# [16, 20, 15, 14, 13]
# shortest path between  13 and 17
# [17, 16, 20, 15, 14, 13]
# shortest path between  14 and 1
# [1, 10, 12, 20, 15, 14]
# shortest path between  14 and 2
# [2, 1, 10, 12, 20, 15, 14]
# shortest path between  14 and 9
# [9, 1, 10, 12, 20, 15, 14]
# shortest path between  14 and 10
# [10, 12, 20, 15, 14]
# shortest path between  14 and 22
# [22, 13, 14]
# shortest path between  14 and 3
# [3, 7, 6, 5, 4, 19, 17, 16, 20, 15, 14]
# shortest path between  14 and 7
# [7, 6, 5, 4, 19, 17, 16, 20, 15, 14]
# shortest path between  14 and 8
# [8, 9, 1, 10, 12, 20, 15, 14]
# shortest path between  14 and 4
# [4, 19, 17, 16, 20, 15, 14]
# shortest path between  14 and 5
# [5, 4, 19, 17, 16, 20, 15, 14]
# shortest path between  14 and 19
# [19, 17, 16, 20, 15, 14]
# shortest path between  14 and 6
# [6, 5, 4, 19, 17, 16, 20, 15, 14]
# shortest path between  14 and 12
# [12, 20, 15, 14]
# shortest path between  14 and 11
# [11, 18, 19, 17, 16, 20, 15, 14]
# shortest path between  14 and 18
# [18, 19, 17, 16, 20, 15, 14]
# shortest path between  14 and 20
# [20, 15, 14]
# shortest path between  14 and 13
# [13, 14]
# shortest path between  14 and 14
# [14]
# shortest path between  14 and 21
# [21, 13, 14]
# shortest path between  14 and 15
# [15, 14]
# shortest path between  14 and 16
# [16, 20, 15, 14]
# shortest path between  14 and 17
# [17, 16, 20, 15, 14]
# shortest path between  21 and 1
# [1, 22, 13, 21]
# shortest path between  21 and 2
# [2, 1, 22, 13, 21]
# shortest path between  21 and 9
# [9, 1, 22, 13, 21]
# shortest path between  21 and 10
# [10, 12, 20, 15, 14, 13, 21]
# shortest path between  21 and 22
# [22, 13, 21]
# shortest path between  21 and 3
# [3, 9, 1, 22, 13, 21]
# shortest path between  21 and 7
# [7, 3, 9, 1, 22, 13, 21]
# shortest path between  21 and 8
# [8, 9, 1, 22, 13, 21]
# shortest path between  21 and 4
# [4, 19, 17, 16, 20, 15, 14, 13, 21]
# shortest path between  21 and 5
# [5, 4, 19, 17, 16, 20, 15, 14, 13, 21]
# shortest path between  21 and 19
# [19, 17, 16, 20, 15, 14, 13, 21]
# shortest path between  21 and 6
# [6, 5, 4, 19, 17, 16, 20, 15, 14, 13, 21]
# shortest path between  21 and 12
# [12, 20, 15, 14, 13, 21]
# shortest path between  21 and 11
# [11, 18, 19, 17, 16, 20, 15, 14, 13, 21]
# shortest path between  21 and 18
# [18, 19, 17, 16, 20, 15, 14, 13, 21]
# shortest path between  21 and 20
# [20, 15, 14, 13, 21]
# shortest path between  21 and 13
# [13, 21]
# shortest path between  21 and 14
# [14, 13, 21]
# shortest path between  21 and 21
# [21]
# shortest path between  21 and 15
# [15, 14, 13, 21]
# shortest path between  21 and 16
# [16, 20, 15, 14, 13, 21]
# shortest path between  21 and 17
# [17, 16, 20, 15, 14, 13, 21]
# shortest path between  15 and 1
# [1, 10, 12, 20, 15]
# shortest path between  15 and 2
# [2, 1, 10, 12, 20, 15]
# shortest path between  15 and 9
# [9, 1, 10, 12, 20, 15]
# shortest path between  15 and 10
# [10, 12, 20, 15]
# shortest path between  15 and 22
# [22, 13, 14, 15]
# shortest path between  15 and 3
# [3, 7, 6, 5, 4, 19, 17, 16, 20, 15]
# shortest path between  15 and 7
# [7, 6, 5, 4, 19, 17, 16, 20, 15]
# shortest path between  15 and 8
# [8, 9, 1, 10, 12, 20, 15]
# shortest path between  15 and 4
# [4, 19, 17, 16, 20, 15]
# shortest path between  15 and 5
# [5, 4, 19, 17, 16, 20, 15]
# shortest path between  15 and 19
# [19, 17, 16, 20, 15]
# shortest path between  15 and 6
# [6, 5, 4, 19, 17, 16, 20, 15]
# shortest path between  15 and 12
# [12, 20, 15]
# shortest path between  15 and 11
# [11, 18, 19, 17, 16, 20, 15]
# shortest path between  15 and 18
# [18, 19, 17, 16, 20, 15]
# shortest path between  15 and 20
# [20, 15]
# shortest path between  15 and 13
# [13, 14, 15]
# shortest path between  15 and 14
# [14, 15]
# shortest path between  15 and 21
# [21, 13, 14, 15]
# shortest path between  15 and 15
# [15]
# shortest path between  15 and 16
# [16, 20, 15]
# shortest path between  15 and 17
# [17, 16, 20, 15]
# shortest path between  16 and 1
# [1, 9, 8, 7, 6, 5, 4, 19, 17, 16]
# shortest path between  16 and 2
# [2, 1, 9, 8, 7, 6, 5, 4, 19, 17, 16]
# shortest path between  16 and 9
# [9, 8, 7, 6, 5, 4, 19, 17, 16]
# shortest path between  16 and 10
# [10, 12, 20, 16]
# shortest path between  16 and 22
# [22, 13, 14, 15, 20, 16]
# shortest path between  16 and 3
# [3, 7, 6, 5, 4, 19, 17, 16]
# shortest path between  16 and 7
# [7, 6, 5, 4, 19, 17, 16]
# shortest path between  16 and 8
# [8, 7, 6, 5, 4, 19, 17, 16]
# shortest path between  16 and 4
# [4, 19, 17, 16]
# shortest path between  16 and 5
# [5, 4, 19, 17, 16]
# shortest path between  16 and 19
# [19, 17, 16]
# shortest path between  16 and 6
# [6, 5, 4, 19, 17, 16]
# shortest path between  16 and 12
# [12, 20, 16]
# shortest path between  16 and 11
# [11, 18, 19, 17, 16]
# shortest path between  16 and 18
# [18, 19, 17, 16]
# shortest path between  16 and 20
# [20, 16]
# shortest path between  16 and 13
# [13, 14, 15, 20, 16]
# shortest path between  16 and 14
# [14, 15, 20, 16]
# shortest path between  16 and 21
# [21, 13, 14, 15, 20, 16]
# shortest path between  16 and 15
# [15, 20, 16]
# shortest path between  16 and 16
# [16]
# shortest path between  16 and 17
# [17, 16]
# shortest path between  17 and 1
# [1, 9, 8, 7, 6, 5, 4, 19, 17]
# shortest path between  17 and 2
# [2, 1, 9, 8, 7, 6, 5, 4, 19, 17]
# shortest path between  17 and 9
# [9, 8, 7, 6, 5, 4, 19, 17]
# shortest path between  17 and 10
# [10, 12, 20, 16, 17]
# shortest path between  17 and 22
# [22, 13, 14, 15, 20, 16, 17]
# shortest path between  17 and 3
# [3, 7, 6, 5, 4, 19, 17]
# shortest path between  17 and 7
# [7, 6, 5, 4, 19, 17]
# shortest path between  17 and 8
# [8, 7, 6, 5, 4, 19, 17]
# shortest path between  17 and 4
# [4, 19, 17]
# shortest path between  17 and 5
# [5, 4, 19, 17]
# shortest path between  17 and 19
# [19, 17]
# shortest path between  17 and 6
# [6, 5, 4, 19, 17]
# shortest path between  17 and 12
# [12, 20, 16, 17]
# shortest path between  17 and 11
# [11, 18, 19, 17]
# shortest path between  17 and 18
# [18, 19, 17]
# shortest path between  17 and 20
# [20, 16, 17]
# shortest path between  17 and 13
# [13, 14, 15, 20, 16, 17]
# shortest path between  17 and 14
# [14, 15, 20, 16, 17]
# shortest path between  17 and 21
# [21, 13, 14, 15, 20, 16, 17]
# shortest path between  17 and 15
# [15, 20, 16, 17]
# shortest path between  17 and 16
# [16, 17]
# shortest path between  17 and 17
# [17]
